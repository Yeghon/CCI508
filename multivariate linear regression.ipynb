# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Kenya_Schools.csv")

# %%
subD = df.loc[df['County'] =='NAIROBI']

# %%
X = subD[['Total Enrolment', 'Total Number of Classrooms']]
y = subD['Pupil Teacher Ratio']

# %%
def plotFunction(x, y):
    plt.figure(figsize=(10,4))
    plt.scatter(x, y)

# %%
# To optimize the data set, divide each value in each column by the maximum values in that column
for i,j in range(len(X)):
    X[i-1] = X[i-1]/np.max(X[i-1])
    X[i-1] = X[i-1]/np.max(X[i-1])
    
X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-416571289811> in <module>
# ...

# %%
# To scale the values of x, use the formula  
'''z = (x - u) / s
where z would be the new value, x the original and u the mean with s being the standrd deviation'''
mean = np.mean(X)
std = np.std(X)
XX = []
for x in range(len(X)):
    x = (x - mean) / std

# %%
X
# Out:
#        Total Enrolment  Total Number of Classrooms   0   1   2   3   4   5  \
# 21                 743                          16 NaN NaN NaN NaN NaN NaN
# 24                   0                           0 NaN NaN NaN NaN NaN NaN
# 32                1606                          24 NaN NaN NaN NaN NaN NaN
# 40                  11                           1 NaN NaN NaN NaN NaN NaN
# 49                  28                           2 NaN NaN NaN NaN NaN NaN
# ...                ...                         ...  ..  ..  ..  ..  ..  ..
# 25915              991                          26 NaN NaN NaN NaN NaN NaN
# 25959              153                           8 NaN NaN NaN NaN NaN NaN
# 25966               39                           4 NaN NaN NaN NaN NaN NaN
# 25968              777                          24 NaN NaN NaN NaN NaN NaN
# 25977              739                          16 NaN NaN NaN NaN NaN NaN
#
# ...

# %%
scaleValues(X)
X
# Out:
#        Total Enrolment  Total Number of Classrooms   0   1   2   3   4   5  \
# 21                 743                          16 NaN NaN NaN NaN NaN NaN
# 24                   0                           0 NaN NaN NaN NaN NaN NaN
# 32                1606                          24 NaN NaN NaN NaN NaN NaN
# 40                  11                           1 NaN NaN NaN NaN NaN NaN
# 49                  28                           2 NaN NaN NaN NaN NaN NaN
# ...                ...                         ...  ..  ..  ..  ..  ..  ..
# 25915              991                          26 NaN NaN NaN NaN NaN NaN
# 25959              153                           8 NaN NaN NaN NaN NaN NaN
# 25966               39                           4 NaN NaN NaN NaN NaN NaN
# 25968              777                          24 NaN NaN NaN NaN NaN NaN
# 25977              739                          16 NaN NaN NaN NaN NaN NaN
#
# ...
