# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
url = 'https://en.wikipedia.org/wiki/Wikipedia:List_of_English_contractions'

# %%
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')

# %%
table = soup.find_all('table', attrs={'class':'wikitable sortable'})

# %%
headers = []
heads = soup.find_all('th')
for x in heads:
    headers.append(x.text)
headers
# Out:
# ['Contraction', 'Meaning\n']

# %%
data = []
tableData = soup.find_all('tr')
for cell in tableData:
    dataRow = []
    td = soup.find_all('td')
    for x in td:
        dataRow.append(x)
    data.append(dataRow)

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#     0                                                  1         2    \
# 0  [[]]  [[[This is an , <a href="/wiki/Wikipedia:Proje...  ['aight]
# 1  [[]]  [[[This is an , <a href="/wiki/Wikipedia:Proje...  ['aight]
# 2  [[]]  [[[This is an , <a href="/wiki/Wikipedia:Proje...  ['aight]
# 3  [[]]  [[[This is an , <a href="/wiki/Wikipedia:Proje...  ['aight]
# 4  [[]]  [[[This is an , <a href="/wiki/Wikipedia:Proje...  ['aight]
#
#            3          4                                                  5    \
# 0  [alright\n]  [[ain't]]  [am not / is not / are not / has not / have no...
# 1  [alright\n]  [[ain't]]  [am not / is not / are not / has not / have no...
# 2  [alright\n]  [[ain't]]  [am not / is not / are not / has not / have no...
# 3  [alright\n]  [[ain't]]  [am not / is not / are not / has not / have no...
# 4  [alright\n]  [[ain't]]  [am not / is not / are not / has not / have no...
#
#          6                      7         8                       9    ...  \
# 0  [[amn't]]  [am not, [[[2]]], \n]  [aren't]  [are not, [[[3]]], \n]  ...
# 1  [[amn't]]  [am not, [[[2]]], \n]  [aren't]  [are not, [[[3]]], \n]  ...
# 2  [[amn't]]  [am not, [[[2]]], \n]  [aren't]  [are not, [[[3]]], \n]  ...
# 3  [[amn't]]  [am not, [[[2]]], \n]  [aren't]  [are not, [[[3]]], \n]  ...
# 4  [[amn't]]  [am not, [[[2]]], \n]  [aren't]  [are not, [[[3]]], \n]  ...
#
#         296                       297       298          299       300  \
# 0  [you'll]  [you shall / you will\n]  [you're]  [you are\n]  [you've]
# 1  [you'll]  [you shall / you will\n]  [you're]  [you are\n]  [you've]
# 2  [you'll]  [you shall / you will\n]  [you're]  [you are\n]  [you've]
# 3  [you'll]  [you shall / you will\n]  [you're]  [you are\n]  [you've]
# 4  [you'll]  [you shall / you will\n]  [you're]  [you are\n]  [you've]
#
#             301           302  \
# 0  [you have\n]  [[noun], 's]
# 1  [you have\n]  [[noun], 's]
# 2  [you have\n]  [[noun], 's]
# 3  [you have\n]  [[noun], 's]
# 4  [you have\n]  [[noun], 's]
#
#                                                  303               304  \
# 0  [[noun],  is (possessive forms of many nouns a...  [[noun(s)], 're]
# 1  [[noun],  is (possessive forms of many nouns a...  [[noun(s)], 're]
# 2  [[noun],  is (possessive forms of many nouns a...  [[noun(s)], 're]
# 3  [[noun],  is (possessive forms of many nouns a...  [[noun(s)], 're]
# 4  [[noun],  is (possessive forms of many nouns a...  [[noun(s)], 're]
#
#                    305
# 0  [[noun(s)],  are\n]
# 1  [[noun(s)],  are\n]
# 2  [[noun(s)],  are\n]
# 3  [[noun(s)],  are\n]
# 4  [[noun(s)],  are\n]
#
# [5 rows x 306 columns]
