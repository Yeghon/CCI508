# %% [markdown]
# # Scrap Jumia for Huawei smartphones appearing on the first page

# %%
from selenium import webdriver
import pandas as pd

# %% [markdown]
# ## Using chrome import chromiu driver

# %%
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
driver.get("https://afrikalyrics.com/willy-paul-nikune-lyrics")

for y in driver.find_elements_by_id('tracks'):
    print(y.text)
# Out:
# (Saldido)
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, pozee
# Nikune, nikune nikune, ooh
# Nikune kune kune kune ma
# Nikune kune kune
# Nikune kune kune kune ma
# Nikune kune kune
# Mwana kipimo usinipimie mama
# Wakati jasho bado sijamwaga
# Sijachoka ndio naanza sasa
# Utamu wa mahaba ndio naleta mama
# Wewe Willy
# Nina swali vile vile kitendawili
# Unaweza kunipenda vile wawili
# Ama ni kesi toka Nandy naye Ali
# Basi tufanye vurugu baba
# Beiby usiwe na shaka
# Kama ni kung'ata nitang'ata utosheke
# And when I do do call me you you
# Hakuna mwingine atakwama juu juu
# Pepecha pepeta ng'a
# Pepecha pepeta sakata Nadia
# Pepeta pepeta ng'a
# Pepeta pepeta pepeta Willy
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, eeh
# Nikune, nikune nikune, ooh
# Nikune kune kune kune ma, ooh
# Nikune kune kune kune kunee, oooh
# Nikune kune kune kune ma, ooh
# Nikune kune kune kune kunee, oooh
# Guza sixpack beiby hii si kitambi
# Twende home karantin tupige kambi
# Napiga nyundo kabati ifeel ndio stamina
# Eeh eh eh eh stamina (Pozeee)
# Acha ning'ate
# Utamu ukizidi nipe sigino
# Nizidishe mauno nikate
# Mpaka kisigino niongeze na miguno
# Onja ladha ya kibaya
# Ukumbuke niaje nitapenda
# Bara tunajimwaya
# Huyu mwenzangu utapenda
# Paramulate
# Lakini polepole nisi-ejaculate
# Tabia ya kwangu soft mama
# Eeh ki-supaghetti
# Pepecha pepeta ng'a
# Pepecha pepeta sakata Nadia
# Pepeta pepeta ng'a
# Pepeta pepeta pepeta Willy
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, ooh
# Nikune, nikune nikune, eeh
# Nikune, nikune nikune, ooh
# Nikune kune kune kune ma, ooh
# Nikune kune kune kune kunee, oooh
# Nikune kune kune kune ma, ooh
# Nikune kune kune kune kunee, oooh
# Beiby nikupeel kama caterpillar
# Nikukate kitu bila ukabila
# Make you feel like a queen
# Milele wewe wangu sio baby mama
# Totoa totoa, totoa mama totoa
# Totoa totoa, totoa mama mmmh
# Kanyaga tena mama rombosa
# Rombosa tena mama kanyaga
# Kanyaga tena mama rombosa
# Rombosa tena mama kanyaga
# Oooh, oooh,ooh
#
#   Correct   All Lyrics by WILLY PAUL   Add Translation
# More Lyrics from Kenya More Afropop Lyrics More Swahili Lyrics
# Afrika Lyrics
# W
# WILLY PAUL Lyrics

# %% [markdown]
# _Loop through the response extracting required items_

# %%
product_name = []
current_price = []
old_price = []
discount = []
rating = []
reviews = []

for x in driver.find_elements_by_class_name('prd'):
    
    # Extract phone name from each cell,
    # use try catch to avoid exceptions
    try:
        product_name.append(x.find_element_by_class_name('name').text)
    except:
        product_name.append("NA")
    
    try:
        current_price.append(x.find_element_by_class_name('prc').text)
    except:
        current_price.append("NA")
        
    try:
        old_price.append(x.find_element_by_class_name('old').text)
    except:
        old_price.append("NA")  
    
    try:
        discount.append(x.find_element_by_class_name('tag').text)
    except:
        discount.append("NA")
    
    try:
        customer_reviews = x.find_element_by_class_name('rev').text
        split_reviews = customer_reviews.split("(")
        rating.append(split_reviews[0].strip("\n"))
        reviews.append(split_reviews[1].strip(")"))
    except:
        rating.append("NA")
        reviews.append("NA")

import pandas as pd
df = pd.DataFrame({'Product':product_name, 'Current Price': current_price, 
                   'Originl Price': old_price, 'Discount':discount, 
                   'Customer Ratings': rating, 'Reviewed By': reviews})
df.to_csv('JumiaHuawei.csv', index=False, encoding='utf8')
df.head(20)
# Out:
#                                               Product Current Price  \
# 0   Huawei Y6s, 6.09" - 3GB/64GB, 3020 MAh, 4G, Du...    KSh 13,199
# 1   Huawei Y6s, 6.09", 3 GB + 64 GB, 3020 MAh, 4G,...    KSh 13,199
# 2   Huawei Y6p,6.3",64GB + 3GB,4G,5000MAh Emrald G...    KSh 14,890
# 3   Huawei Y6s, 6.09",64GB+3GB RAM(Dual SIM),-Blue...    KSh 13,095
# 4   Huawei Y6p,6.3",64GB+3GB(Dual Sim), 5000 MAh P...    KSh 14,999
# 5   Huawei Y5 Lite, 5.45" 16GB ROM + 1 GB RAM (Sin...     KSh 8,500
# 6   Huawei Y8p, 6.3" OLED, 128GB + 6GB(Dual SIM), ...    KSh 20,699
# 7   Huawei Y6s, 6.09" - 3GB + 64GB, 4G (Dual SIM),...    KSh 13,299
# 8   Huawei Y6s, 6.09"-3GB/64GB,3020 MAh, Dual -Sta...    KSh 13,499
# 9   Huawei Y9s, 6.59", 128 GB + 6 GB (Dual SIM) - ...    KSh 24,799
# 10  Huawei Y6p, 6.3", 64GB +3GB,5000 MAh- Emerald ...    KSh 15,499
# 11  Huawei Y6s, 6.09" - 3GB/64GB, 3020 MAh, 4G, Du...    KSh 13,300
# 12  Huawei Y9A, 6.63"+128GB + 8GB (Dual SIM) 4200 ...    KSh 30,900
# 13  Huawei Y6p, 64GB + 3GB, 6.3",13MP Camera, 5000...    KSh 14,399
# 14  Huawei Nova 7i, 6.4", 128GB + 8GB, 4200 MAh, 4...    KSh 28,999
# 15  Huawei Y6p 6.3", 3GB+64GB,Dual, 5000MAh, Black...    KSh 16,599
# 16  Huawei Y7p, 6.39" 64GB+4GB,48MP+8MP+2MP- Blue+...    KSh 17,593
# 17  Huawei Y8s, 6.5", 64GB + 4GB, 4000 MAh, 4G (Du...    KSh 15,999
# 18  Huawei Y6s, 6.09" - 3GB/64GB, 3020 MAh, 4G, Du...    KSh 12,499
# 19  Huawei Y6P, 6.3", 64 GB + 3 GB RAM, 5000 MAh -...    KSh 14,450
#
#    Originl Price        Discount Customer Ratings Reviewed By
# 0     KSh 16,999             22%     4.6 out of 5          15
# 1     KSh 16,999             22%     4.6 out of 5          29
# 2     KSh 19,999             26%     4.5 out of 5           2
# 3     KSh 17,999             27%       4 out of 5           9
# 4     KSh 19,000             21%     4.5 out of 5           6
# 5     KSh 14,500             41%     4.3 out of 5           7
# 6     KSh 28,999  Official Store               NA          NA
# 7     KSh 14,499              8%       4 out of 5           3
# 8     KSh 15,000             10%     4.5 out of 5          24
# 9     KSh 32,999  Official Store     4.5 out of 5          37
# 10    KSh 19,999             23%               NA          NA
# 11    KSh 14,999             11%               NA          NA
# 12    KSh 39,000             21%               NA          NA
# 13    KSh 22,000             35%     4.7 out of 5           3
# 14    KSh 35,000             17%     4.5 out of 5           2
# 15    KSh 21,999             25%               NA          NA
# 16    KSh 25,999             32%               NA          NA
# 17    KSh 20,999  Official Store               NA          NA
# 18    KSh 18,000             31%       5 out of 5           1
# 19    KSh 19,999             28%     3.2 out of 5           5

# %%
''' for a number of songs, extract their lyrics from the same website'''
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
mySource = ['nadia-mukami-radio-love', 'makadem-orudo-aye']
baseUrl = "https://afrikalyrics.com/"
artist = []
lyrics = []
for x in mySource:
    driver.get(baseUrl + x + "-lyrics")
    for y in driver.find_elements_by_id('tracks'):
        artist.append(x)
        lyrics.append(y.text)
df = pd.DataFrame({'Artist': artist, 'Lyrics': lyrics})
df.to_csv("mySongs.csv", index=False, encoding='utf8')

# %%
df.head()
# Out:
#                     Artist                                             Lyrics
# 0  nadia-mukami-radio-love    Ooooh...Nadia\nDem call me Arrow Bwoy\nVicky...
