# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from math import sqrt

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 3C62-F0AB
#
#  Directory of C:\Users\brian.samba\Documents\Computation Intelligence\ML\Classification
#
# 01/12/2020  20:31    <DIR>          .
# 01/12/2020  20:31    <DIR>          ..
# 01/12/2020  18:36    <DIR>          .ipynb_checkpoints
# 01/12/2020  16:18            46,443 data_banknote_authentication.csv
# 01/12/2020  09:36            46,443 data_banknote_authentication.txt
# 01/12/2020  09:54            12,410 LoanAgeDefault_data.xlsx
# 01/12/2020  20:31            80,851 Nearest Neighbor from sractch.ipynb
# 01/12/2020  17:52            11,163 Nearest Neighbors, Decision Trees and Naives Bayes - Scikitlearn Implementation - Predicting Fake and Genuine Currency.ipynb
# 01/12/2020  20:02               763 nearest_neighbors.py
# 01/12/2020  09:28             9,300 seeds_dataset.txt
#                7 File(s)        207,373 bytes
#                3 Dir(s)  128,992,870,400 bytes free

# %%
data = pd.read_csv("data_banknote_authentication.csv")

# %%
data.shape
# Out:
# (1372, 5)

# %%
data.head()
# Out:
#    Variance   Skewness  Kurtosis  Entropy  Class
# 0    3.62160    8.6661   -2.8073 -0.44699      0
# 1    4.54590    8.1674   -2.4586 -1.46210      0
# 2    3.86600   -2.6383    1.9242  0.10645      0
# 3    3.45660    9.5228   -4.0112 -3.59440      0
# 4    0.32924   -4.4552    4.5718 -0.98880      0

# %%
d_samples = data.iloc[:,:4]
target = data['Class']

# %%
#target.head()
#for point in range(len(d_samples)-1):
#    print(np.array(d_samples.iloc[point]))

test = d_samples.to_numpy()
values = test.tolist()

# %%
def euclidean_distance(row1, row2):
    "Calculate the distance between the value to be predicted and the already labelled values"

    distance = 0.0
    for i in range(len(row1)-1):
        distance += (row1[i]-row2[i])**2
    return sqrt(distance)

row0 = values[0]
distances = []

for row in values:
    distance = euclidean_distance(row0, row)
    distances.append(distance)

# %%
len(distances)
# Out:
# 1372

# %%
distances.sort()

# %%
print(distances)
# Out:
# [0.0, 0.27698940412947193, 0.2913406940336347, 0.4280281415981899, 0.4325756581223682, 0.4800827636980938, 0.5391080503943525, 0.5927419927759465, 0.7173199983271066, 0.7486190018961587, 0.824940931218715, 1.0596899782483553, 1.0734958826190253, 1.0766332476753628, 1.081936384451507, 1.094174478773838, 1.1066272498000396, 1.1129561716437895, 1.1276644314688655, 1.1556028643093614, 1.1693841242295022, 1.1733003707491108, 1.1910384628549997, 1.2452468429994108, 1.2725401486790113, 1.3164182124233919, 1.334609197480671, 1.3509736155824814, 1.4046161539723234, 1.4095898481473248, 1.4181858023545433, 1.4242311083528545, 1.4385849887997584, 1.446778853176946, 1.4502530986003783, 1.4593212703171288, 1.4867868374450988, 1.4875971833799633, 1.495685561874554, 1.5036863303229169, 1.5067773060409426, 1.5074811839621742, 1.51094261969143, 1.5138903560033663, 1.5252919392693327, 1.5332967097075503, 1.5384471944139002, 1.5450135695196974, 1.549630284938959, 1.5506790028887345, 1.5728741017640293, 
# ...
